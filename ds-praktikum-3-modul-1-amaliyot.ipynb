# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
df = pd.read_csv("melb_data.csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# Yuqoridagi jadval Avstraliyaning Melburn shahridagi sotiladigna uylar haqidagi ma'lumotlarni jamlagan. Batafsil https://www.kaggle.com/dansbecker/melbourne-housing-snapshot/home

# %% [markdown]
# ## TASK 1: Print the number of rows of df

# %%
#Type your answer here
len(df)
# Out:
# 13580

# %% [markdown]
# ## TASK 2. Output statistics about df

# %%
#Type your answer here

df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# ## TASK 3: Print the number of NaN values ​​in each column

# %%
#Type your answer here
nan_value=df.isna().sum()

# %%
nan_value
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ## TASK 4. Find the percentage of NaN values ​​for each column

# %%
#Type your answer here
nan_value/len(df)
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.004566
# Landsize         0.000000
# BuildingArea     0.474963
# YearBuilt        0.395803
# CouncilArea      0.100810
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %% [markdown]
# ## TASK 5. Discard all rows containing NaNs (DO NOT STORE the result!!!)

# %%
#Type your answer here
df.dropna()
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4        Abbotsford      55a Park St      4    h  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000.0      S
# 7        Abbotsford    98 Charles St      2    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 12205    Whittlesea    30 Sherwin St      3    h   601000.0      S
# 12206  Williamstown      75 Cecil St      3    h  1050000.0     VB
# 12207  Williamstown    2/29 Dover Rd      1    u   385000.0     SP
# 12209       Windsor  201/152 Peel St      2    u   560000.0     PI
# 12212    Yarraville  54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# ...

# %% [markdown]
# ##   TASK 6. Drop all columns with NaN (DO NOT STORE the result!!!)

# %%
#Javobingizni shu yerga yozing
df.dropna(axis=1)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Landsize  \
# ...

# %% [markdown]
# ## TASK 7. Drop the NaN rows in the column with the most NaN values ​​(DO NOT STORE the result!!!)

# %%
#Write your answer here
#First of all, We should find max Nan column ,using this following mixed methods
max_nan_column=df.isna().sum().idxmax()
# Then I apply dropna() method 
n=df[max_nan_column].dropna()

# %%
len(n)-len(df)
# Out:
# -6450

# %% [markdown]
# ## TASK 8. Drop NaN rows of a column with at least NaN values ​​and store the result in the original df.

# %%
#Write your answer here
min_nan_column=df.isna().sum().idxmin()
df[min_nan_column].dropna(inplace=True)

# %% [markdown]
# ## 9-VAZIFA. Yakuniy `df` ni `hdf` formatida saqlab qo'ying
# Kaggle da fayllarni o'ng burchakda `Data` tugmasini bosish orqali ko'rish (yuklab olish) mumkin:
#
# ![](https://i.imgur.com/UeVJbf6.png)

# %%
#Javobingizni shu yerga yozing

# %% [markdown]
# ## 10-VAZIFA. Yuqoridagi `df` ni yangi `melb_data.csv` fayliga yozib oling va `hdf` fayl bilan birga GitHub akkauntingizga yuklang.
# **`df` indeksini `csv` faylga yozmang!**
#
# Keyingi amaliyotda bu fayllardan foydalanamiz.
#
# Faylni kaggledan kompyuterga yuklab olish:
#
# ![](https://i.imgur.com/xXTCJmi.png)
# ![](https://i.imgur.com/0OqZsSu.png)

# %%
#Javobingizni shu yerga yozing
